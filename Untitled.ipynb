# %%
from scipy.stats import multivariate_normal
import scipy.io
import numpy as  np
plc = scipy.io.loadmat('plc.mat')['plc']
import matplotlib.pyplot as plt

# %%
from scipy.fftpack import dct
def dct2 (block):
  return dct(dct(block.T, norm = 'ortho').T, norm = 'ortho')

# %%
#import cv2 as cv
#img= cv.imread('cheetah.bmp', cv.IMREAD_GRAYSCALE)
#out = cv.normalize(img.astype('float'), None, 0.0, 1.0, cv.NORM_MINMAX)
#img

# %%
image = scipy.io.loadmat('image.mat')['I']
plt.imshow(image, cmap='gray', vmin=0, vmax=1)
image
# Out:
# array([[0.23921569, 0.23529412, 0.2       , ..., 0.32156863, 0.16078431,
#         0.        ],
#        [0.23529412, 0.23529412, 0.21568627, ..., 0.30196078, 0.15686275,
#         0.        ],
#        [0.24313725, 0.23921569, 0.22745098, ..., 0.27843137, 0.15294118,
#         0.        ],
#        ...,
#        [0.35686275, 0.38431373, 0.39607843, ..., 0.31372549, 0.17647059,
#         0.        ],
#        [0.37647059, 0.41176471, 0.43921569, ..., 0.29019608, 0.16862745,
#         0.        ],
#        [0.44313725, 0.46666667, 0.51764706, ..., 0.27058824, 0.16078431,
#         0.        ]])
